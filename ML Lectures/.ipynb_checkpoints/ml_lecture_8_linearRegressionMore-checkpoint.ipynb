# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import time

# %%
df = pd.read_csv(r"../DataSets/CarPrice_Assignment.csv")

# %%
df.shape
# Out:
# (205, 26)

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
num_col = df.select_dtypes(exclude="object")

# %%
num_col.columns
# Out:
# Index(['car_ID', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
colsDrp = ['symboling', 'carheight', 'stroke', "compressionratio", "peakrpm", "CarName"]
df.drop(columns = colsDrp, axis=1, inplace = True)

# %%
cat_col = df.select_dtypes(include = ["object"]).columns
df[cat_col].nunique()
# Out:
# fueltype          2
# aspiration        2
# doornumber        2
# carbody           5
# drivewheel        3
# enginelocation    2
# enginetype        7
# cylindernumber    7
# fuelsystem        8
# dtype: int64

# %%
df = pd.get_dummies(columns=['fueltype', 'aspiration', 'doornumber', 'drivewheel', 'enginelocation'], data=df, drop_first= True )

# %%
df.head()
# Out:
#    car_ID      carbody  wheelbase  carlength  carwidth  curbweight enginetype  \
# 0       1  convertible       88.6      168.8      64.1        2548       dohc
# 1       2  convertible       88.6      168.8      64.1        2548       dohc
# 2       3    hatchback       94.5      171.2      65.5        2823       ohcv
# 3       4        sedan       99.8      176.6      66.2        2337        ohc
# 4       5        sedan       99.4      176.6      66.4        2824        ohc
#
#   cylindernumber  enginesize fuelsystem  ...  horsepower  citympg  highwaympg  \
# 0           four         130       mpfi  ...         111       21          27
# 1           four         130       mpfi  ...         111       21          27
# 2            six         152       mpfi  ...         154       19          26
# 3           four         109       mpfi  ...         102       24          30
# 4           five         136       mpfi  ...         115       18          22
#
#      price  fueltype_gas  aspiration_turbo  doornumber_two  drivewheel_fwd  \
# 0  13495.0          True             False            True           False
# 1  16500.0          True             False            True           False
# 2  16500.0          True             False            True           False
# 3  13950.0          True             False           False            True
# 4  17450.0          True             False           False           False
#
#    drivewheel_rwd  enginelocation_rear
# 0            True                False
# 1            True                False
# 2            True                False
# 3           False                False
# 4           False                False
#
# [5 rows x 21 columns]

# %%
from sklearn.preprocessing import StandardScaler, OrdinalEncoder

# %%
encoder = OrdinalEncoder()
for i in df.select_dtypes(include='object').columns:
    df[i] = encoder.fit_transform(df[[i]])

# %%
X = df.drop('price', axis = 1)
y = df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 20)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression, Ridge

# %% [markdown]
# # Model 1 : Multiple Linear Regression (All Features)

# %%
rgsr = LinearRegression()

# %%
model = rgsr.fit(X_train_scaled, y_train)

# %%
y_pred = model.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('--- MLR (All Features) ---')
print(f'Mean Absolute Error = {mae:.2f}')
print(f'Root Mean Squared Error = {rmse:.2f}')
print(f'R-Squared Score = {r2*100:.2f} %\n')
# Out:
# --- MLR (All Features) ---
# Mean Absolute Error = 1970.16
# Root Mean Squared Error = 2421.17
# R-Squared Score = 83.18 %

# %% [markdown]
# # Visualization

# %%
pip install yellowbrick
# Out:
# Collecting yellowbrick
#   Downloading yellowbrick-1.5-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from yellowbrick) (3.10.6)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from yellowbrick) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from yellowbrick) (1.7.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from yellowbrick) (2.3.5)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\m.aheed siddiqui\new_anaconda\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.5.0)
# Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
# Installing collected packages: yellowbrick
# Successfully installed yellowbrick-1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from yellowbrick.regressor import PredictionError

# %% [markdown]
# # Initialize the visualization model

# %%
visualizer = PredictionError(rgsr)

# %%
visualizer.fit(X_train_scaled, y_train)

visualizer.score(X_test_scaled, y_test)

visualizer.show()
# Out:
# <Axes: title={'center': 'Prediction Error for LinearRegression'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
#model 2-Feature selection (SFS)

# %%
rgsr=LinearRegression()

# %%
from sklearn.feature_selection import SequentialFeatureSelector as sfs

# %%
selector=sfs(rgsr,n_features_to_select=5,direction='backward')
selector=selector.fit(X_train_scaled,y_train)

#get the names
selected_features=list(X.columns[selector.get_support()] )
print(selected_features)

#slice the orignal data frame
X_train_selected=X_train[selected_features]
X_test_selected=X_test[selected_features]

#Re scale
scaler_new=StandardScaler()
X_train_sel_scaled=scaler_new.fit_transform(X_train_selected)
X_test_sel_scaled=scaler_new.transform(X_test_selected)

#Fit the model
model=rgsr.fit(X_train_sel_scaled,y_train)
# Out:
# ['car_ID', 'wheelbase', 'enginesize', 'horsepower', 'enginelocation_rear']

# %%
y_pred_sfs=model.predict(X_test_sel_scaled)

# %%
mae_sfs=mean_absolute_error(y_test,y_pred_sfs)
mse_sfs=mean_squared_error(y_test,y_pred_sfs)
rmse_sfs=np.sqrt(mse_sfs)
r2_sfs=r2_score(y_test,y_pred_sfs)

print("MLR (SFS selected features)")
print(f"Selected features: {list(X.columns[selector.get_support()])}")
print(f"Mean absolute error={mae:.2f}")
print(f"Root mean squared error={rmse:.2f}")
print(f"R squared score:{r2*100:.2f}%\n")
# Out:
# MLR (SFS selected features)
# Selected features: ['car_ID', 'wheelbase', 'enginesize', 'horsepower', 'enginelocation_rear']
# Mean absolute error=1970.16
# Root mean squared error=2421.17
# R squared score:83.18%
