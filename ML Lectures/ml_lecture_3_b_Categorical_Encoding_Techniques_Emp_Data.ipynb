# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"../DataSets/emp.csv")

# %%
df.head()
# Out:
#    empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30

# %%
# Target Encoding

df2 = df.copy()

# %%
sorted(df2["job"].unique())
# Out:
# ['ANALYST', 'CLERK', 'MANAGER', 'PRESIDENT', 'SALESMAN']

# %%
df2['job'].value_counts()
# Out:
# job
# SALESMAN     4
# CLERK        4
# MANAGER      3
# ANALYST      2
# PRESIDENT    1
# Name: count, dtype: int64

# %%
cols_nums = {"job": {'ANALYST':3, 'CLERK':5, 'MANAGER':2, 'PRESIDENT':1, 'SALESMAN':4}}

# %%
df2 = df2.replace(cols_nums)
df2.head()
# Out:
#    empno   ename  job     mgr    hiredate  sal    comm  deptno
# 0   7839    KING    1     NaN  11/17/2001    1     NaN      10
# 1   7698   BLAKE    2  7839.0  05/01/2001    2     NaN      30
# 2   7782   CLARK    2  7839.0  06/09/2001    2     NaN      10
# 3   7566   JONES    2  7839.0  04/02/2001    2     NaN      20
# 4   7654  MARTIN    4  7698.0  09/28/2001    3  1400.0      30

# %%
def salCatg(salary):
    if salary>=3000:
        r=1
    elif salary>=1500:
        r=2
    else:
        r=3
    return r

# %%
df2['sal'] = df2['sal'].apply(salCatg)
df2.head()
# Out:
#    empno   ename  job     mgr    hiredate  sal    comm  deptno
# 0   7839    KING    1     NaN  11/17/2001    3     NaN      10
# 1   7698   BLAKE    2  7839.0  05/01/2001    3     NaN      30
# 2   7782   CLARK    2  7839.0  06/09/2001    3     NaN      10
# 3   7566   JONES    2  7839.0  04/02/2001    3     NaN      20
# 4   7654  MARTIN    4  7698.0  09/28/2001    3  1400.0      30

# %%
# Label Encoding applies to category data types

df3 = df.copy()
df3.dtypes
# Out:
# empno         int64
# ename        object
# job          object
# mgr         float64
# hiredate     object
# sal           int64
# comm        float64
# deptno        int64
# dtype: object

# %%
df3['job'] = df3["job"].astype('category')
df3.dtypes
# Out:
# empno          int64
# ename         object
# job         category
# mgr          float64
# hiredate      object
# sal            int64
# comm         float64
# deptno         int64
# dtype: object

# %%
sorted(df3["job"].unique())
# Out:
# ['ANALYST', 'CLERK', 'MANAGER', 'PRESIDENT', 'SALESMAN']

# %%
df3
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  12/03/2001   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001  1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0  12/17/2000   800     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  04/19/2007  3000     NaN      20
# ...

# %%
df3['job1'] = df3['job'].astype('category').cat.codes
df3.head()
# Out:
#    empno   ename        job     mgr    hiredate   sal    comm  deptno  job1
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10     3
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30     2
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10     2
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20     2
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30     4

# %%
df3['comm'] = df3['comm'].astype('category').cat.codes
df3.head()
# Out:
#    empno   ename        job     mgr    hiredate   sal  comm  deptno  job1
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000    -1      10     3
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850    -1      30     2
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450    -1      10     2
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975    -1      20     2
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250     3      30     4

# %%
# One hot encoder dummy encoding

df4 = df.copy()

# %%
sorted(df4["deptno"].unique())
# Out:
# [np.int64(10), np.int64(20), np.int64(30)]

# %%
df4['depID']=df4.deptno
df4
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno  depID
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10     10
# 1    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30     30
# 2    7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10     10
# 3    7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20     20
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30     30
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001  1600   300.0      30     30
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001  1500     0.0      30     30
# 7    7900   JAMES      CLERK  7698.0  12/03/2001   950     NaN      30     30
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001  1250   500.0      30     30
# 9    7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20     20
# 10   7369   SMITH      CLERK  7902.0  12/17/2000   800     NaN      20     20
# ...

# %%
# Custom Binary Encoding
import numpy as np
df3["cBE_Code"]=np.where(df3["hiredate"].str.contains("2001"), 1, 0)

# %%
df3[["ename", "hiredate", "cBE_Code"]].head(16)
# Out:
#      ename    hiredate  cBE_Code
# 0     KING  11/17/2001         1
# 1    BLAKE  05/01/2001         1
# 2    CLARK  06/09/2001         1
# 3    JONES  04/02/2001         1
# 4   MARTIN  09/28/2001         1
# 5    ALLEN  02/20/2001         1
# 6   TURNER  09/08/2001         1
# 7    JAMES  12/03/2001         1
# 8     WARD  02/22/2001         1
# 9     FORD  02/03/2001         1
# 10   SMITH  12/17/2000         0
# 11   SCOTT  04/19/2007         0
# 12   ADAMS  05/23/2007         0
# 13  MILLER  01/23/2002         0

# %%
# One Hot Encoder
# !pip install category_encoders
import category_encoders as ce

# %%
df5 = df.copy()

# %%
encoder = ce.OneHotEncoder(cols='deptno', use_cat_names=True)
df5['depID'] = df5.deptno
data_encoded = encoder.fit_transform(df5)
data_encoded
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno_10.0  \
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN            1
# 1    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN            0
# 2    7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN            1
# 3    7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN            0
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0            0
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001  1600   300.0            0
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001  1500     0.0            0
# 7    7900   JAMES      CLERK  7698.0  12/03/2001   950     NaN            0
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001  1250   500.0            0
# 9    7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN            0
# 10   7369   SMITH      CLERK  7902.0  12/17/2000   800     NaN            0
# ...

# %%
# Ordinal Encoder
from sklearn.preprocessing import OrdinalEncoder

# %%
sorted(df3['deptno'].unique())
# Out:
# [np.int64(10), np.int64(20), np.int64(30)]

# %%
ord_enc = OrdinalEncoder()
df3["dno_code"] = ord_enc.fit_transform(df3[["deptno"]])
df3[['ename', "deptno", "dno_code"]].head(14)
# Out:
#      ename  deptno  dno_code
# 0     KING      10       0.0
# 1    BLAKE      30       2.0
# 2    CLARK      10       0.0
# 3    JONES      20       1.0
# 4   MARTIN      30       2.0
# 5    ALLEN      30       2.0
# 6   TURNER      30       2.0
# 7    JAMES      30       2.0
# 8     WARD      30       2.0
# 9     FORD      20       1.0
# 10   SMITH      20       1.0
# 11   SCOTT      20       1.0
# 12   ADAMS      20       1.0
# 13  MILLER      10       0.0
